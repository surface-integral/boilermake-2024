# %%
# !pip3 install pandas
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (1.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/prisoe/Library/Python/3.11/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in /Users/prisoe/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip3 install --upgrade pip

# %%
import pandas as pd
# Out:
# /var/folders/pn/8gcx0rw94c1cp5dfznjxk6xr0000gn/T/ipykernel_56689/217833862.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("dev.csv")
df.head()
# Out:
#                                             Question Numbers  \
# 0  number0 red apples and number1 green apples ar...     7 2
# 1  ellen has number0 more balls than marin . mari...     6 9
# 2  janet has number0 oranges and sharon has numbe...     9 7
# 3  allan brought number0 balloons and jake brough...     2 4
# 4  adam has number0 more apples than jackie . jac...     5 9
#
#             Equation  Answer                              group_nums  Grade  \
# 0  + number0 number1     9.0   [0, 1, 2, 3, 4, 5, 6, 10, 16, 17, 18]      1
# 1  + number0 number1    15.0  [1, 2, 3, 4, 5, 9, 10, 11, 16, 17, 18]      1
# 2  + number0 number1    16.0          [1, 2, 3, 6, 7, 8, 16, 17, 18]      1
# 3  + number0 number1     6.0          [1, 2, 3, 6, 7, 8, 21, 22, 23]      1
# 4  + number0 number1    14.0  [1, 2, 3, 4, 5, 9, 10, 11, 16, 17, 18]      1
#
#        Type                                               Body  \
# 0  Addition  number0 red apples and number1 green apples ar...
# 1  Addition  ellen has number0 more balls than marin . mari...
# 2  Addition  janet has number0 oranges and sharon has numbe...
# 3  Addition  allan brought number0 balloons and jake brough...
# 4  Addition  adam has number0 more apples than jackie . jac...
#
#                                       Ques_Statement
# 0                how many apples are in the basket ?
# 1                   how many balls does ellen have ?
# 2  how many oranges do janet and sharon have toge...
# 3  how many balloons did allan and jake have in t...
# 4                   how many apples does adam have ?

# %%
question_prompts = []

print(df.shape)
for i in range (df.shape[0]):
    line = df["Question"][i]
    if (len(df["Numbers"][i].split()) == 2):
        number0 = df["Numbers"][i].split()[0]
        number1 = df["Numbers"][i].split()[1]
        line = line[0: line.index("number0")] + str(number0) + line[line.index("number0")+7:]
        line = line[0: line.index("number1")] + str(number1) + line[line.index("number1")+7:]
        question_prompts.append(line)
    else: 
        df = df.drop(i)


df["question_prompts"] = question_prompts
df.head()
# Out:
# (238, 9)
#                                             Question Numbers  \
# 0  number0 red apples and number1 green apples ar...     7 2
# 1  ellen has number0 more balls than marin . mari...     6 9
# 2  janet has number0 oranges and sharon has numbe...     9 7
# 3  allan brought number0 balloons and jake brough...     2 4
# 4  adam has number0 more apples than jackie . jac...     5 9
#
#             Equation  Answer                              group_nums  Grade  \
# 0  + number0 number1     9.0   [0, 1, 2, 3, 4, 5, 6, 10, 16, 17, 18]      1
# 1  + number0 number1    15.0  [1, 2, 3, 4, 5, 9, 10, 11, 16, 17, 18]      1
# 2  + number0 number1    16.0          [1, 2, 3, 6, 7, 8, 16, 17, 18]      1
# 3  + number0 number1     6.0          [1, 2, 3, 6, 7, 8, 21, 22, 23]      1
# 4  + number0 number1    14.0  [1, 2, 3, 4, 5, 9, 10, 11, 16, 17, 18]      1
#
#        Type                                               Body  \
# 0  Addition  number0 red apples and number1 green apples ar...
# 1  Addition  ellen has number0 more balls than marin . mari...
# 2  Addition  janet has number0 oranges and sharon has numbe...
# 3  Addition  allan brought number0 balloons and jake brough...
# 4  Addition  adam has number0 more apples than jackie . jac...
#
#                                       Ques_Statement  \
# 0                how many apples are in the basket ?
# 1                   how many balls does ellen have ?
# 2  how many oranges do janet and sharon have toge...
# 3  how many balloons did allan and jake have in t...
# 4                   how many apples does adam have ?
#
#                                     question_prompts
# 0  7 red apples and 2 green apples are in the bas...
# 1  ellen has 6 more balls than marin . marin has ...
# 2  janet has 9 oranges and sharon has 7 oranges ....
# 3  allan brought 2 balloons and jake brought 4 ba...
# 4  adam has 5 more apples than jackie . jackie ha...

# %%
addition_df = df.loc[df['Type'] == 'Addition']
subtraction = df.loc[df['Type'] == 'Subtraction']
multiplication = df.loc[df['Type'] == 'Multiplication']
division = df.loc[df['Type'] == 'Division']

# %%
addition_df.head(10)
# Out:
#                                              Question Numbers  \
# 0   number0 red apples and number1 green apples ar...     7 2
# 1   ellen has number0 more balls than marin . mari...     6 9
# 2   janet has number0 oranges and sharon has numbe...     9 7
# 3   allan brought number0 balloons and jake brough...     2 4
# 4   adam has number0 more apples than jackie . jac...     5 9
# 5   brian has number0 more plums than paul . paul ...     4 7
# 6   sandra took number0 cups of coffee and marcie ...     6 2
# 8   number0 red plums and number1 green plums are ...    14 4
# 9   marin has number0 apples and donald has number...     9 2
# 11  number0 red peaches and number1 green peaches ...    5 14
#
#              Equation  Answer                              group_nums  Grade  \
# 0   + number0 number1     9.0   [0, 1, 2, 3, 4, 5, 6, 10, 16, 17, 18]      1
# 1   + number0 number1    15.0  [1, 2, 3, 4, 5, 9, 10, 11, 16, 17, 18]      1
# 2   + number0 number1    16.0          [1, 2, 3, 6, 7, 8, 16, 17, 18]      1
# 3   + number0 number1     6.0          [1, 2, 3, 6, 7, 8, 21, 22, 23]      1
# 4   + number0 number1    14.0  [1, 2, 3, 4, 5, 9, 10, 11, 16, 17, 18]      1
# 5   + number0 number1    11.0  [1, 2, 3, 4, 5, 9, 10, 11, 16, 17, 18]      1
# 6   + number1 number0     8.0         [1, 2, 3, 8, 9, 10, 23, 24, 25]      1
# 8   + number1 number0    18.0       [0, 1, 2, 3, 4, 5, 6, 16, 17, 18]      1
# 9   + number0 number1    11.0          [1, 2, 3, 6, 7, 8, 16, 17, 18]      1
# 11  + number0 number1    19.0       [0, 1, 2, 3, 4, 5, 6, 16, 17, 18]      1
#
#         Type                                               Body  \
# 0   Addition  number0 red apples and number1 green apples ar...
# 1   Addition  ellen has number0 more balls than marin . mari...
# 2   Addition  janet has number0 oranges and sharon has numbe...
# 3   Addition  allan brought number0 balloons and jake brough...
# 4   Addition  adam has number0 more apples than jackie . jac...
# 5   Addition  brian has number0 more plums than paul . paul ...
# 6   Addition  sandra took number0 cups of coffee and marcie ...
# 8   Addition  number0 red plums and number1 green plums are ...
# 9   Addition  marin has number0 apples and donald has number...
# 11  Addition  number0 red peaches and number1 green peaches ...
#
#                                        Ques_Statement  \
# 0                 how many apples are in the basket ?
# 1                    how many balls does ellen have ?
# 2   how many oranges do janet and sharon have toge...
# 3   how many balloons did allan and jake have in t...
# 4                    how many apples does adam have ?
# 5                    how many plums does brian have ?
# 6   how many cups of coffee did sandra and marcie ...
# 8                  how many plums are in the basket ?
# 9   how many apples do marin and donald have toget...
# 11               how many peaches are in the basket ?
#
#                                      question_prompts
# 0   7 red apples and 2 green apples are in the bas...
# 1   ellen has 6 more balls than marin . marin has ...
# 2   janet has 9 oranges and sharon has 7 oranges ....
# 3   allan brought 2 balloons and jake brought 4 ba...
# 4   adam has 5 more apples than jackie . jackie ha...
# 5   brian has 4 more plums than paul . paul has 7 ...
# 6   sandra took 6 cups of coffee and marcie took 2...
# 8   14 red plums and 4 green plums are in the bask...
# 9   marin has 9 apples and donald has 2 apples . h...
# 11  5 red peaches and 14 green peaches are in the ...

# %%
# addition parsing 

types = [] 

addition_df = addition_df.reset_index() 

for i in range(addition_df.shape[0]):
    question = addition_df["Question"][i]
    if (('more' in question) | ('than' in question)):
        types.append("more than")
    elif (('and' in question) | ('another' in question) | ('total' in question) | ('altogether' in question)):
        types.append("and")
    else: 
        types.append("original amount")

addition_df["Subtype"] = types
morethan_addition_df = addition_df.loc[addition_df['Subtype'] == 'more than']
and_addition_df = addition_df.loc[addition_df['Subtype'] == 'and']
findorigamount_addition_df = addition_df.loc[addition_df['Subtype'] == 'original amount']
print("total addition problems: "+str(len(addition_df)))
print("more than addition problems: "+str(len(morethan_addition_df)))
print("and addition problems: "+str(len(and_addition_df)))
print("find original amount addition problems: "+str(len(findorigamount_addition_df)))

and_addition_df.head()
# Out:
# total addition problems: 46
# more than addition problems: 14
# and addition problems: 24
# find original amount addition problems: 8
#    index                                           Question Numbers  \
# 0      0  number0 red apples and number1 green apples ar...     7 2
# 2      2  janet has number0 oranges and sharon has numbe...     9 7
# 3      3  allan brought number0 balloons and jake brough...     2 4
# 6      6  sandra took number0 cups of coffee and marcie ...     6 2
# 7      8  number0 red plums and number1 green plums are ...    14 4
#
#             Equation  Answer                             group_nums  Grade  \
# 0  + number0 number1     9.0  [0, 1, 2, 3, 4, 5, 6, 10, 16, 17, 18]      1
# 2  + number0 number1    16.0         [1, 2, 3, 6, 7, 8, 16, 17, 18]      1
# 3  + number0 number1     6.0         [1, 2, 3, 6, 7, 8, 21, 22, 23]      1
# 6  + number1 number0     8.0        [1, 2, 3, 8, 9, 10, 23, 24, 25]      1
# 7  + number1 number0    18.0      [0, 1, 2, 3, 4, 5, 6, 16, 17, 18]      1
#
#        Type                                               Body  \
# 0  Addition  number0 red apples and number1 green apples ar...
# 2  Addition  janet has number0 oranges and sharon has numbe...
# 3  Addition  allan brought number0 balloons and jake brough...
# 6  Addition  sandra took number0 cups of coffee and marcie ...
# 7  Addition  number0 red plums and number1 green plums are ...
#
#                                       Ques_Statement  \
# 0                how many apples are in the basket ?
# 2  how many oranges do janet and sharon have toge...
# 3  how many balloons did allan and jake have in t...
# 6  how many cups of coffee did sandra and marcie ...
# 7                 how many plums are in the basket ?
#
#                                     question_prompts Subtype
# 0  7 red apples and 2 green apples are in the bas...     and
# 2  janet has 9 oranges and sharon has 7 oranges ....     and
# 3  allan brought 2 balloons and jake brought 4 ba...     and
# 6  sandra took 6 cups of coffee and marcie took 2...     and
# 7  14 red plums and 4 green plums are in the bask...     and

# %%
final = {"Question":[], "Subject1":[], "Quantity1":[], "Subject2":[], "Quantity2":[], "Operation":[], "Type":[]}

for add_type in [[morethan_addition, "more_than"], [and_addition, "total"], [findorigamount_addition, "find_original_amound"]]:
    for row in add_type[0]:
        final["Question"].append(row["Question"])
        final["Subject1"]
# Out:
# ellen has number0 more balls than marin . marin has number1 balls . how many balls does ellen have ?
# adam has number0 more apples than jackie . jackie has number1 apples . how many apples does adam have ?
# brian has number0 more plums than paul . paul has number1 plums . how many plums does brian have ?
# number0 peaches are in the basket . number1 more peaches are put in the basket . how many peaches are in the basket now ?
# number0 birds were sitting on the fence . number1 more birds came to join them . how many birds are sitting on the fence ?
# number0 owls were sitting on the fence . number1 more owls joined them . how many owls are on the fence now ?
# number0 toucans are sitting on a tree limb . number1 more toucan joins them . how many toucans in all ?
# shelby 's teacher gives out gold stars for great math work . yesterday shelby earned number0 gold stars . today she earned number1 more . how many gold stars did shelby earn in all ?
# the book nook sold number0 computer books last week . the sold number1 more cook books than computer books . how many cook books did the book nook sell ?
# paul and vinnie deliver newspapers . paul made $ number0 in tips . vinnie made $ number1 more than paul . how much did vinnie make ?
# emily owned number0 songs by her favorite artists . later on she bought number1 more songs . how many songs did she have totaled ?
# a group of number0 friends were playing video games . later number1 more friends came over . how many people were there total ?
# jerry had number0 action figures on a shelf in his room . later he added number1 more figures to the shelf . how many action figures were on his shelf total ?
# there were number0 people in line at lunch when number1 more got in line . how many people were there total in line ?
# number0 red apples and number1 green apples are in the basket . how many apples are in the basket ?
# janet has number0 oranges and sharon has number1 oranges . how many oranges do janet and sharon have together ?
# allan brought number0 balloons and jake brought number1 balloons to the park . how many balloons did allan and jake have in the park ?
# sandra took number0 cups of coffee and marcie took number1 cups of coffee . how many cups of coffee did sandra and marcie take in total ?
# number0 red plums and number1 green plums are in the basket . how many plums are in the basket ?
# marin has number0 apples and donald has number1 apples . how many apples do marin and donald have together ?
# number0 red peaches and number1 green peaches are in the basket . how many peaches are in the basket ?
# mary 's mom is getting ready for mary 's birthday party . she blew up number0 balloons this morning and number1 balloons this afternoon . how many balloons did she blow up in all ?
# the litter patrol picked up number0 glass bottles and number1 aluminum cans on saturday . how many pieces of litter did they pick up altogether ?
# lucy went to the grocery store . she bought number0 packs of cookies and number1 packs of noodles . how many packs of groceries did she buy in all ?
# roden went to a pet shop . he bought number0 gold fish and number1 blue fish . how many fish did he buy ?
# i read number0 pages of my english book yesterday . today i read number1 pages . what is the total number of pages did i read ?
# in a school there are number0 girls and number1 boys . how many pupils are there in that school ?
# linda has number0 candies . chloe has number1 how many candies do they have in all ?
# jose has number0 chickens and number1 ducks . how many fowls does he have ?
# elizabeth studied number0 minutes for her science test . she studied number1 minutes for her math test . how long did elizabeth study altogether ?
# will was drawing super heroes on a sheet of scrap paper . he drew number0 heroes on the front and number1 heroes on the back . how many heroes did he draw total ?
# a chef used number0 potatoes to make fries for the lunch crowd . later he used another number1 potatoes for the dinner crowd . how many potatoes did he use total ?
# for a potluck lunch bianca brought number0 bottles of soda . if someone else had already brought number1 sodas how many were there total ?
# rachel had to complete number0 pages of math homework and number1 pages of reading homework . how many pages did she have to complete total ?
# debby received number0 text messages before noon and another number1 after noon . how many text messages did debby receive total ?
# sam was playing basketball with his friend . sam scored number0 points and his friend scored number1 points . how many points did they score total ?
# a pet store had number0 kittens . if they got another number1 kittens how many would they have total ?
# at the fair haley went on number0 rides in the day and number1 at night . how many rides did haley go on total ?
# some oranges were in the basket . number0 oranges were taken from the basket . now there are number1 oranges . how many oranges were in the basket before some of the oranges were taken ?
# mikayla has a huge collection of music cds . she gave number0 cds to her friend . now she has number1 cds left . how many cds were in mikayla 's collection at first ?
# there is a snail problem in centerville . people work together to get rid number0 snails but number1 of them remain . about how many snails were originally in centerville ?
# the book fair sold number0 posters . now they have number1 posters left . how many posters did they have to begin with ?
# cody had a bag of marbles . later he gave number0 to his brother . now cody has number1 marbles . how many marbles did cody have to start with ?
# rachel took number0 dollars from her piggy bank . now she has number1 dollars in her piggy bank . how much money was originally in there ?
# at the arcade dave spent number0 tickets on stuffed tiger . then he had number1 left . how many tickets did dave have to start with ?
# olivia gave her cat number0 cheese cubes . now olivia has number1 cheese cubes left . how many cheese cubes did olivia have originally ?

# %%
import spacy 
from spacy import displacy
from spacy.lang.en.stop_words import STOP_WORDS

NER = spacy.load("en_core_web_sm")

# %%
def contains_num(text):
    l = [True if "NUM" == token.pos_ else False for token in text]
    return (True in l)

def andrew_function(question, operation, problem_type): 
    output = {"Question":"", "Subject1":"", "Quantity1":"", "Subject2":"", "Quantity2":"", "Operation":"", "Type":""}
    output["Question"] = question
    output["Operation"] = operation
    output["Type"] = problem_type

    doc = NER(question)

    sents = [] 
    subject = ""
    for sent in doc.sents: 
        sents.append(sent)
    for sent in sents[:len(sents)-1]:
        print(sent)
        for token in sent:
            if (("subj" in token.dep_) or ("dobj" in token.dep_)):
                subtree = list(token.subtree)
                start = subtree[0].i
                end = subtree[-1].i + 1
                adj = ""
                contains_num = [True if "NUM" == token.pos_ else False for token in doc[start:end]]
                contains_noun = [True if "NOUN" == token.pos_ else False for token in doc[start:end]]
                k = 0 
                seg1 = doc[start:end]
                print(seg1)
                seg2 = ""
                for token in doc[start:end]:
                    if (token.pos_ == "CCONJ"): 
                        if True in [True if "NUM" == token.pos_ else False for token in doc[k+1:]]: 
                            seg1 = doc[start:k]
                            seg2 = doc[k+1:]
                    k += 1 
                for seg in (seg1, seg2): 
                    if seg: 
                        if ((True in contains_num) and (True in contains_noun)):
                            for token in seg[:contains_noun.index(True)+1]:
                                if (token.pos_ == "NUM"): 
                                    if output["Quantity1"] == "":
                                        #print("first quantity:" +token.text)
                                        output["Quantity1"] = token.text
                                    else: 
                                        #print("second quantity:" +token.text)
                                        output["Quantity2"] = token.text
                                if ((token.pos_ == "ADJ") and (token.text != "more")): 
                                    adj = token.text
                                if ((token.pos_ == "NOUN")):   # filter to only nouns 
                                    subject = adj+" "+token.text
                                    if output["Subject1"] == "":
                                        #print("first subject:" +subject)
                                        output["Subject1"] = subject
                                    else: 
                                        #print("second subject:" +subject)
                                        output["Subject2"] = subject
                                    adj = ""
    if output["Subject2"] == "": 
        output["Subject2"] = subject

    return output 

output = andrew_function("ellen has 4 more balls than marin . marin has 8 balls . how many balls does ellen have ?", "Addition", "and")

print("Question: "+output["Question"])
print("Subject1: "+output["Subject1"])
print("Quantity1: "+output["Quantity1"])
print("Subject2: "+output["Subject2"])
print("Quantity2: "+output["Quantity2"])
print("Type: "+output["Type"])
print("Operation: "+output["Operation"])
# Out:
# ellen has 4 more balls than marin .
# ellen
# 4 more balls than marin
# marin has 8 balls .
# marin
# 8 balls
# Question: ellen has 4 more balls than marin . marin has 8 balls . how many balls does ellen have ?
# Subject1:  balls
# Quantity1: 4
# Subject2:  balls
# Quantity2: 8
# Type: and
# Operation: Addition

# %%
final = {"Question":[], "Subject1":[], "Quantity1":[], "Subject2":[], "Quantity2":[], "Operation":[], "Type":[]}
doc = nlp("7 red apples and 2 green apples are in the basket . how many apples are in the basket ?")
doc = nlp("ellen has 4 more balls than marin . marin has 8 balls . how many balls does ellen have ?")

# for add_type in [[morethan_addition, "more_than"], [and_addition, "total"], [findorigamount_addition, "find_original_amound"]]:
#     for i in range(len(add_type[0])):
#         row = add_type[0][i]
#         output = andrew_function(row["question_prompts"], "Addition", add_type[1])

#and_addition_df = and_addition_df.reset_index()

print(and_addition_df.shape[0])
for i in range(and_addition_df.shape[0]): 
    output = andrew_function(and_addition_df["question_prompts"][i], "Addition", "And") 
    for col in output:
        final[col].append(output[col])

final_df = pd.DataFrame(final)
final_df
        

# print(len(final["Subject1"]))
# for i in range(len(final["Question"])):
#     print("Question: "+final["Question"][i])
#     print("Subject1: "+final["Subject1"][i])
#     print("Quantity1: "+final["Quantity1"][i])
#     print("Subject2: "+final["Subject2"][i])
#     print("Quantity2: "+final["Quantity2"][i])
#     print("Type: "+final["Type"][i])
#     print("Operation: "+final["Operation"][i])
# Out:
# 24
# 7 red apples and 2 green apples are in the basket .
# 7 red apples and 2 green apples
# janet has 9 oranges and sharon has 7 oranges .
# janet
# 9 oranges
# sharon
# 7 oranges
# allan brought 2 balloons and jake brought 4 balloons to the park .
# allan
# 2 balloons and jake
# 4 balloons
# sandra took 6 cups of coffee and marcie took 2 cups of coffee .
# sandra
# 6 cups of coffee
# marcie
# 2 cups of coffee
# 14 red plums and 4 green plums are in the basket .
# 14 red plums and 4 green plums
# marin has 9 apples and donald has 2 apples .
# marin
# 9 apples and donald
# 2 apples
# 5 red peaches and 14 green peaches are in the basket .
# 5 red peaches and 14 green peaches
# mary 's mom is getting ready for mary 's birthday party .
# mary 's mom
# she blew up 6 balloons this morning and 5 balloons this afternoon .
# she
# 6 balloons
# the litter patrol picked up 10 glass bottles and 8 aluminum cans on saturday .
# the litter patrol
# 10 glass bottles and 8 aluminum cans
# lucy went to the grocery store .
# lucy
# she bought 12 packs of cookies and 16 packs of noodles .
# she
# 12 packs of cookies and 16 packs of noodles
# roden went to a pet shop .
# roden
# he bought 15 gold fish and 7 blue fish .
# he
# 15 gold fish and 7 blue fish
# i read 21 pages of my english book yesterday .
# i
# 21 pages of my english book
# today i read 17 pages .
# i
# 17 pages
# in a school there are 542 girls and 387 boys .
# linda has 34 candies .
# linda
# 34 candies
# jose has 28 chickens and 18 ducks .
# jose
# 28 chickens and 18 ducks
# elizabeth studied 25 minutes for her science test .
# elizabeth
# 25 minutes
# she studied 35 minutes for her math test .
# she
# will was drawing super heroes on a sheet of scrap paper .
# super heroes
# he drew 2 heroes on the front and 7 heroes on the back .
# he
# 2 heroes
# a chef used 5 potatoes to make fries for the lunch crowd .
# a chef
# 5 potatoes
# fries for the lunch crowd
# later he used another 2 potatoes for the dinner crowd .
# he
# another 2 potatoes
# for a potluck lunch bianca brought 9 bottles of soda .
# a potluck lunch bianca
# 9 bottles of soda
# rachel had to complete 9 pages of math homework and 2 pages of reading homework .
# rachel
# 9 pages of math homework and 2 pages of reading homework
# homework
# debby received 21 text messages before noon and another 18 after noon .
# debby
# 21 text messages
# sam was playing basketball with his friend .
# sam
# basketball
# sam scored 75 points and his friend scored 12 points .
# sam
# his friend
# a pet store had 6 kittens .
# a pet store
# 6 kittens
# at the fair haley went on 6 rides in the day and 3 at night .
#                                              Question     Subject1 Quantity1  \
# 0   7 red apples and 2 green apples are in the bas...   red apples         7
# 1   janet has 9 oranges and sharon has 7 oranges ....      oranges         9
# 2   allan brought 2 balloons and jake brought 4 ba...     balloons         4
# 3   sandra took 6 cups of coffee and marcie took 2...         cups         6
# 4   14 red plums and 4 green plums are in the bask...    red plums        14
# 5   marin has 9 apples and donald has 2 apples . h...       apples         2
# 6   5 red peaches and 14 green peaches are in the ...  red peaches         5
# 7   mary 's mom is getting ready for mary 's birth...     balloons         6
# 8   the litter patrol picked up 10 glass bottles a...                     10
# 9   lucy went to the grocery store . she bought 12...        store
# 10  roden went to a pet shop . he bought 15 gold f...     pet shop
# 11  i read 21 pages of my english book yesterday ....        pages        21
# 12  in a school there are 542 girls and 387 boys ....
# 13  linda has 34 candies . chloe has 28 how many c...      candies        34
# 14  jose has 28 chickens and 18 ducks . how many f...     chickens
# 15  elizabeth studied 25 minutes for her science t...      minutes        25
# 16  will was drawing super heroes on a sheet of sc...       heroes         2
# 17  a chef used 5 potatoes to make fries for the l...     potatoes         5
# 18  for a potluck lunch bianca brought 9 bottles o...      bottles         9
# 19  rachel had to complete 9 pages of math homewor...         math         9
# 20  debby received 21 text messages before noon an...         text        21
# 21  sam was playing basketball with his friend . s...
# 22  a pet store had 6 kittens . if they got anothe...      kittens         6
# 23  at the fair haley went on 6 rides in the day a...
#
#          Subject2 Quantity2 Operation Type
# 0    green apples         2  Addition  And
# 1         oranges         7  Addition  And
# 2        balloons            Addition  And
# 3            cups         2  Addition  And
# 4     green plums         4  Addition  And
# 5          apples            Addition  And
# 6   green peaches        14  Addition  And
# 7        balloons            Addition  And
# 8                            Addition  And
# 9           store            Addition  And
# 10       pet shop            Addition  And
# 11          pages        17  Addition  And
# 12                           Addition  And
# 13        candies            Addition  And
# 14       chickens            Addition  And
# 15        minutes            Addition  And
# 16         heroes            Addition  And
# 17       potatoes         2  Addition  And
# 18        bottles            Addition  And
# 19           math            Addition  And
# 20           text            Addition  And
# 21                           Addition  And
# 22        kittens            Addition  And
# 23                           Addition  And

# %%
final_addition_df = pd.DataFrame(final)
final_addition_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/prisoe/boilermake-2024/data_analysis.ipynb Cell 16 line 1
# ----> <a href='vscode-notebook-cell:/Users/prisoe/boilermake-2024/data_analysis.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> final_addition_df = pd.DataFrame(final)
#       <a href='vscode-notebook-cell:/Users/prisoe/boilermake-2024/data_analysis.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a> final_addition_df.head()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:767, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     761     mgr = self._init_mgr(
#     762         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     763     )
#     765 elif isinstance(data, dict):
#     766     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 767     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     768 elif isinstance(data, ma.MaskedArray):
#     769     from numpy.ma import mrecords
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
doc = nlp("ellen has 4 more balls than marin . marin has 8 balls . how many balls does ellen have ?")
#doc = nlp("7 red apples and 3 green apples are in the basket . how many apples are in the basket ?")


sents = [] 
for sent in doc.sents: 
    sents.append(sent)
for sent in sents[:len(sents)-1]:
    for token in sent:
        if (("nsubj" in token.dep_) | ("dobj" in token.dep_)):
            subtree = list(token.subtree)
            print("Subtree: " + str(subtree))
            start = subtree[0].i
            end = subtree[-1].i + 1
            adj = ""
            contains_num = [True if "NUM" == token.pos_ else False for token in doc[start:end]]
            contains_noun = [True if "NOUN" == token.pos_ else False for token in doc[start:end]]
            print(doc[start:end])
            if True in contains_num:
                for token in doc[start:end][:contains_noun.index(True)+1]:
                    if (token.pos_ == "NUM"): 
                        print("quantity:" +token.text)
                        if final["Quantity1"] == "":
                            print("first quantity:" +token.text)
                            #final["Quantity1"].append(token.text)
                        else: 
                            print("second quantity:" +token.text)
                            #final["Quantity2"].append(token.text)
                    if ((token.pos_ == "ADJ") & (token.text != "more")): 
                        adj = token.text
                    if ((token.pos_ == "NOUN")):   # filter to only nouns 
                        if (adj): 
                            print("subject:" +adj+" "+str(token.text))
                            # if len(final["Subject1"]) == i:
                            #     print("first subject:" +token.text)
                            #     final["Quantity1"].append(adj+str(token.text))
                            # else: 
                            #     print("second subject:" +token.text)
                            #     final["Quantity2"].append(adj+str(token.text))
                            #     print("subject: "+adj+" "+str(token))
                        else: 
                            print("subject:" +adj+str(token.text))
                        adj = ""; 
            contains_num = False
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1f75f194eb4a4e53a1f869c354023271-0" class="displacy" width="3025" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">ellen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">4</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">more</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">balls</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">than</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">marin .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">marin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">8</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">balls .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">how</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">many</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">balls</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">does</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">ellen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">have ?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1f75f194eb4a4e53a1f869c354023271-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1f75f194eb4a4e53a1f869c354023271-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1f75f194eb4a4e53a1f869c354023271-0-1" stroke-width="2px" d="M420,264.5 C420,89.5 745.0,89.5 745.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1f75f194eb4a4e53a1f869c354023271-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1f75f194eb4a4e53a1f869c354023271-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1f75f194eb4a4e53a1f869c354023271-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M565.0,266.5 L573.0,254.5 557.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1f75f194eb4a4e53a1f869c354023271-0-3" stroke-width="2px" d="M245,264.5 C245,2.0 750.0,2.0 750.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1f75f194eb4a4e53a1f869c354023271-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,266.5 L758.0,254.5 742.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1f75f194eb4a4e53a1f869c354023271-0-4" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1f75f194eb4a4e53a1f869c354023271-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,266.5 L923.0,254.5 907.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1f75f194eb4a4e53a1f869c354023271-0-5" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.
# Subtree: [ellen]
# Start = 0
# End = 1
# ellen
# Subtree: [4, more, balls, than, marin]
# Start = 2
# End = 7
# 4 more balls than marin
# quantity:4
# second quantity:4
# subject:balls
# Subtree: [marin]
# Start = 8
# End = 9
# marin
# Subtree: [8, balls]
# Start = 10
# End = 12
# 8 balls
# quantity:8
# second quantity:8
# subject:balls

# %%
spacy.explain("amod")
# Out:
# 'adjectival modifier'

# %%
doc = nlp("ellen has 4 more balls than marin . marin has 8 balls . how many balls does ellen have ?")
displacy.serve(doc, style="dep")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/spacy/displacy/__init__.py:106: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4b02576920584e4e976863f659d9f200-0" class="displacy" width="3025" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">ellen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">4</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">more</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">balls</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">than</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">marin .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">marin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">8</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">balls .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">how</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">many</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">balls</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">does</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">ellen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">have ?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b02576920584e4e976863f659d9f200-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b02576920584e4e976863f659d9f200-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b02576920584e4e976863f659d9f200-0-1" stroke-width="2px" d="M420,264.5 C420,89.5 745.0,89.5 745.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b02576920584e4e976863f659d9f200-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b02576920584e4e976863f659d9f200-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b02576920584e4e976863f659d9f200-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M565.0,266.5 L573.0,254.5 557.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b02576920584e4e976863f659d9f200-0-3" stroke-width="2px" d="M245,264.5 C245,2.0 750.0,2.0 750.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b02576920584e4e976863f659d9f200-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,266.5 L758.0,254.5 742.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b02576920584e4e976863f659d9f200-0-4" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b02576920584e4e976863f659d9f200-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,266.5 L923.0,254.5 907.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b02576920584e4e976863f659d9f200-0-5" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
def function(sentence):
